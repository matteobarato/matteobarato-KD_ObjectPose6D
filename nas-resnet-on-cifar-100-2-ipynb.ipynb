# %%
# !pip install pytorch-lightning
# !pip install torch_pruning
# Out:
# Requirement already satisfied: pytorch-lightning in /home/matteo/miniconda3/envs/net36/lib/python3.6/site-packages (1.5.10)
# Requirement already satisfied: future>=0.17.1 in /home/matteo/miniconda3/envs/net36/lib/python3.6/site-packages (from pytorch-lightning) (0.18.2)
# Requirement already satisfied: tensorboard>=2.2.0 in /home/matteo/miniconda3/envs/net36/lib/python3.6/site-packages (from pytorch-lightning) (2.9.1)
# Requirement already satisfied: torch>=1.7.* in /home/matteo/miniconda3/envs/net36/lib/python3.6/site-packages (from pytorch-lightning) (1.10.1)
# Requirement already satisfied: PyYAML>=5.1 in /home/matteo/miniconda3/envs/net36/lib/python3.6/site-packages (from pytorch-lightning) (5.4.1)
# Requirement already satisfied: typing-extensions in /home/matteo/miniconda3/envs/net36/lib/python3.6/site-packages (from pytorch-lightning) (4.1.1)
# Requirement already satisfied: fsspec[http]!=2021.06.0,>=2021.05.0 in /home/matteo/miniconda3/envs/net36/lib/python3.6/site-packages (from pytorch-lightning) (2022.1.0)
# Requirement already satisfied: torchmetrics>=0.4.1 in /home/matteo/miniconda3/envs/net36/lib/python3.6/site-packages (from pytorch-lightning) (0.8.2)
# Requirement already satisfied: packaging>=17.0 in /home/matteo/miniconda3/envs/net36/lib/python3.6/site-packages (from pytorch-lightning) (21.3)
# Requirement already satisfied: numpy>=1.17.2 in /home/matteo/miniconda3/envs/net36/lib/python3.6/site-packages (from pytorch-lightning) (1.18.1)
# Requirement already satisfied: pyDeprecate==0.3.1 in /home/matteo/miniconda3/envs/net36/lib/python3.6/site-packages (from pytorch-lightning) (0.3.1)
# Requirement already satisfied: setuptools==59.5.0 in /home/matteo/miniconda3/envs/net36/lib/python3.6/site-packages (from pytorch-lightning) (59.5.0)
# Requirement already satisfied: tqdm>=4.41.0 in /home/matteo/miniconda3/envs/net36/lib/python3.6/site-packages (from pytorch-lightning) (4.64.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /home/matteo/miniconda3/envs/net36/lib/python3.6/site-packages (from tensorboard>=2.2.0->pytorch-lightning) (0.4.6)
# Requirement already satisfied: grpcio>=1.24.3 in /home/matteo/miniconda3/envs/net36/lib/python3.6/site-packages (from tensorboard>=2.2.0->pytorch-lightning) (1.47.0)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in /home/matteo/miniconda3/envs/net36/lib/python3.6/site-packages (from tensorboard>=2.2.0->pytorch-lightning) (3.19.4)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /home/matteo/miniconda3/envs/net36/lib/python3.6/site-packages (from tensorboard>=2.2.0->pytorch-lightning) (2.8.0)
# Requirement already satisfied: requests<3,>=2.21.0 in /home/matteo/miniconda3/envs/net36/lib/python3.6/site-packages (from tensorboard>=2.2.0->pytorch-lightning) (2.22.0)
# Requirement already satisfied: wheel>=0.26 in /home/matteo/miniconda3/envs/net36/lib/python3.6/site-packages (from tensorboard>=2.2.0->pytorch-lightning) (0.33.6)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /home/matteo/miniconda3/envs/net36/lib/python3.6/site-packages (from tensorboard>=2.2.0->pytorch-lightning) (0.6.1)
# Requirement already satisfied: markdown>=2.6.8 in /home/matteo/miniconda3/envs/net36/lib/python3.6/site-packages (from tensorboard>=2.2.0->pytorch-lightning) (3.3.7)
# Requirement already satisfied: absl-py>=0.4 in /home/matteo/miniconda3/envs/net36/lib/python3.6/site-packages (from tensorboard>=2.2.0->pytorch-lightning) (1.1.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /home/matteo/miniconda3/envs/net36/lib/python3.6/site-packages (from tensorboard>=2.2.0->pytorch-lightning) (1.8.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /home/matteo/miniconda3/envs/net36/lib/python3.6/site-packages (from tensorboard>=2.2.0->pytorch-lightning) (2.0.3)
# Requirement already satisfied: dataclasses; python_version < "3.7" in /home/matteo/miniconda3/envs/net36/lib/python3.6/site-packages (from torch>=1.7.*->pytorch-lightning) (0.8)
# Requirement already satisfied: aiohttp; extra == "http" in /home/matteo/miniconda3/envs/net36/lib/python3.6/site-packages (from fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning) (3.8.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /home/matteo/miniconda3/envs/net36/lib/python3.6/site-packages (from packaging>=17.0->pytorch-lightning) (3.0.4)
# Requirement already satisfied: importlib-resources; python_version < "3.7" in /home/matteo/miniconda3/envs/net36/lib/python3.6/site-packages (from tqdm>=4.41.0->pytorch-lightning) (5.4.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /home/matteo/miniconda3/envs/net36/lib/python3.6/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.2.0->pytorch-lightning) (1.3.1)
# Requirement already satisfied: six>=1.5.2 in /home/matteo/miniconda3/envs/net36/lib/python3.6/site-packages (from grpcio>=1.24.3->tensorboard>=2.2.0->pytorch-lightning) (1.12.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /home/matteo/miniconda3/envs/net36/lib/python3.6/site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4; python_version >= "3.6" in /home/matteo/miniconda3/envs/net36/lib/python3.6/site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning) (4.8)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /home/matteo/miniconda3/envs/net36/lib/python3.6/site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning) (4.2.4)
# Requirement already satisfied: idna<2.9,>=2.5 in /home/matteo/miniconda3/envs/net36/lib/python3.6/site-packages (from requests<3,>=2.21.0->tensorboard>=2.2.0->pytorch-lightning) (2.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /home/matteo/miniconda3/envs/net36/lib/python3.6/site-packages (from requests<3,>=2.21.0->tensorboard>=2.2.0->pytorch-lightning) (1.25.7)
# Requirement already satisfied: certifi>=2017.4.17 in /home/matteo/miniconda3/envs/net36/lib/python3.6/site-packages (from requests<3,>=2.21.0->tensorboard>=2.2.0->pytorch-lightning) (2021.5.30)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /home/matteo/miniconda3/envs/net36/lib/python3.6/site-packages (from requests<3,>=2.21.0->tensorboard>=2.2.0->pytorch-lightning) (3.0.4)
# Requirement already satisfied: importlib-metadata>=4.4; python_version < "3.10" in /home/matteo/miniconda3/envs/net36/lib/python3.6/site-packages (from markdown>=2.6.8->tensorboard>=2.2.0->pytorch-lightning) (4.8.3)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /home/matteo/miniconda3/envs/net36/lib/python3.6/site-packages (from aiohttp; extra == "http"->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning) (4.0.2)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/matteo/miniconda3/envs/net36/lib/python3.6/site-packages (from aiohttp; extra == "http"->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning) (5.2.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in /home/matteo/miniconda3/envs/net36/lib/python3.6/site-packages (from aiohttp; extra == "http"->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning) (1.7.2)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /home/matteo/miniconda3/envs/net36/lib/python3.6/site-packages (from aiohttp; extra == "http"->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning) (2.1.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/matteo/miniconda3/envs/net36/lib/python3.6/site-packages (from aiohttp; extra == "http"->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning) (1.2.0)
# Requirement already satisfied: asynctest==0.13.0; python_version < "3.8" in /home/matteo/miniconda3/envs/net36/lib/python3.6/site-packages (from aiohttp; extra == "http"->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning) (0.13.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/matteo/miniconda3/envs/net36/lib/python3.6/site-packages (from aiohttp; extra == "http"->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning) (1.2.0)
# Requirement already satisfied: idna-ssl>=1.0; python_version < "3.7" in /home/matteo/miniconda3/envs/net36/lib/python3.6/site-packages (from aiohttp; extra == "http"->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning) (1.1.0)
# Requirement already satisfied: attrs>=17.3.0 in /home/matteo/miniconda3/envs/net36/lib/python3.6/site-packages (from aiohttp; extra == "http"->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning) (19.3.0)
# Requirement already satisfied: zipp>=3.1.0; python_version < "3.10" in /home/matteo/miniconda3/envs/net36/lib/python3.6/site-packages (from importlib-resources; python_version < "3.7"->tqdm>=4.41.0->pytorch-lightning) (3.6.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /home/matteo/miniconda3/envs/net36/lib/python3.6/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.2.0->pytorch-lightning) (3.2.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /home/matteo/miniconda3/envs/net36/lib/python3.6/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning) (0.4.8)
# Requirement already satisfied: torch_pruning in /home/matteo/miniconda3/envs/net36/lib/python3.6/site-packages (0.2.7)
# Requirement already satisfied: torch in /home/matteo/miniconda3/envs/net36/lib/python3.6/site-packages (from torch_pruning) (1.10.1)
# Requirement already satisfied: typing-extensions in /home/matteo/miniconda3/envs/net36/lib/python3.6/site-packages (from torch->torch_pruning) (4.1.1)
# Requirement already satisfied: dataclasses; python_version < "3.7" in /home/matteo/miniconda3/envs/net36/lib/python3.6/site-packages (from torch->torch_pruning) (0.8)

# %%
# Downalod ResNet18 weights
# !wget -nc http://cipizio.it/storage/Nas-ResNet/resnet18_net_e_199.pth
# !mkdir checkpoint
# !mv resnet18_net_e_199.pth ./checkpoint

# Download trained student with gates and stricsigmoid activation on 30 epochs with ADAM
!#wget -nc http://cipizio.it/storage/Nas-ResNet/student_e50_ADAM_stricsig_lre-2_lp_e-4_dw_8.pth
#!mkdir checkpoint
#!mv student_e50_ADAM_stricsig_lre-2_lp_e-4_dw_8.pth ./checkpoint

# %%
'''Train CIFAR10 with PyTorch.'''
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import torch.backends.cudnn as cudnn

import torchvision
import torchvision.transforms as transforms
import src.utils as utils
from src.KD import GatedKD
from src.models import ResNet18
from pytorch_lightning import Trainer, seed_everything
from pytorch_lightning.callbacks.early_stopping import EarlyStopping


import torch_pruning as tp

import os
import argparse

# %%
best_acc = 0  # best test accuracy
start_epoch = 0  # start from epoch 0 or last checkpoint epoch
args = {'resume':False, 'lr':0.001, 'lambda_gating':0.1}
seed_everything(42, workers=True)
# Out:
# Global seed set to 42
# 42

# %% [markdown]
# ## Dataset CIFAR10

# %%
# Data
torch.manual_seed(43)
print('==> Preparing data..')
transform_train = transforms.Compose([
    transforms.RandomCrop(32, padding=4),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010)),
])

transform_test = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010)),
])




trainset = torchvision.datasets.CIFAR10(
    root='./data', train=True, download=True, transform=transform_train)

val_size = 5000
train_size = len(trainset) - val_size

trainset, validationset = torch.utils.data.random_split(trainset, [train_size, val_size])

train_dataloaders = torch.utils.data.DataLoader(
    trainset, batch_size=128, shuffle=True, num_workers=2, pin_memory=True)
val_dataloaders = torch.utils.data.DataLoader(
    validationset, batch_size=128, shuffle=False, num_workers=2, pin_memory=True)

testset = torchvision.datasets.CIFAR10(
    root='./data', train=False, download=True, transform=transform_test)
test_dataloaders = torch.utils.data.DataLoader(
    testset, batch_size=100, shuffle=False, num_workers=2, pin_memory=True)

classes = ('plane', 'car', 'bird', 'cat', 'deer',
           'dog', 'frog', 'horse', 'ship', 'truck')
# Out:
# ==> Preparing data..
# Files already downloaded and verified
# Files already downloaded and verified

# %% [markdown]
# ## Model

# %%
args['lr'] = 1e-3
args['lambda_penalty'] = 1e-5
args['distill_weight'] = 0.9

teacher_model = ResNet18(pretrained=True, remove_avg_pool_layer=True, lr=args['lr'], optim='sgd', scheduler_t_max=200)
student_model = ResNet18(lr=args['lr'], optim='adam', scheduler_t_max=200, use_gates_with_penalty=args['lambda_penalty'])

a = student_model.apply_gates()

# %% [markdown]
# ## Train Teacher

# %%
teacher_trainer = Trainer(deterministic=True,  callbacks=[EarlyStopping(monitor="val_loss", mode="min")],  min_steps=100, max_steps=200)
teacher_trainer.fit(teacher_model, train_dataloaders, val_dataloaders)
# Out:
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
#
#   | Name          | Type             | Params
# ---------------------------------------------------
# 0 | model         | ResNet           | 11.2 M
# 1 | criterion     | CrossEntropyLoss | 0
# 2 | val_accuracy  | Accuracy         | 0
# 3 | test_accuracy | Accuracy         | 0
# ---------------------------------------------------
# 11.2 M    Trainable params
# 0         Non-trainable params
# 11.2 M    Total params
# 44.727    Total estimated model params size (MB)
# Validation sanity check: 0it [00:00, ?it/s]
# /home/matteo/miniconda3/envs/net36/lib/python3.6/site-packages/pytorch_lightning/trainer/data_loading.py:133: UserWarning: The dataloader, val_dataloader 0, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 8 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
#   f"The dataloader, {name}, does not have many workers which may be a bottleneck."
# Global seed set to 42
# /home/matteo/miniconda3/envs/net36/lib/python3.6/site-packages/pytorch_lightning/trainer/data_loading.py:133: UserWarning: The dataloader, train_dataloader, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 8 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
#   f"The dataloader, {name}, does not have many workers which may be a bottleneck."
# Training: 0it [00:00, ?it/s]
# torch.Size([128, 10]) torch.Size([128])
# /home/matteo/miniconda3/envs/net36/lib/python3.6/site-packages/pytorch_lightning/loops/optimization/closure.py:36: LightningDeprecationWarning: One of the returned values {'preds'} has a `grad_fn`. We will detach it automatically but this behaviour will change in v1.6. Please detach it manually: `return {'loss': ..., 'something': something.detach()}`
#   f"One of the returned values {set(extra.keys())} has a `grad_fn`. We will detach it automatically"
# torch.Size([128, 10]) torch.Size([128])
# torch.Size([128, 10]) torch.Size([128])
# torch.Size([128, 10]) torch.Size([128])
# torch.Size([128, 10]) torch.Size([128])
# torch.Size([128, 10]) torch.Size([128])
# torch.Size([128, 10]) torch.Size([128])
# torch.Size([128, 10]) torch.Size([128])
# torch.Size([128, 10]) torch.Size([128])
# torch.Size([128, 10]) torch.Size([128])
# torch.Size([128, 10]) torch.Size([128])
# torch.Size([128, 10]) torch.Size([128])
# torch.Size([128, 10]) torch.Size([128])
# torch.Size([128, 10]) torch.Size([128])
# torch.Size([128, 10]) torch.Size([128])
# torch.Size([128, 10]) torch.Size([128])
# torch.Size([128, 10]) torch.Size([128])
# torch.Size([128, 10]) torch.Size([128])
# torch.Size([128, 10]) torch.Size([128])
# torch.Size([128, 10]) torch.Size([128])
# torch.Size([128, 10]) torch.Size([128])
# torch.Size([128, 10]) torch.Size([128])
# torch.Size([128, 10]) torch.Size([128])

# %% [markdown]
# ## Training Student KD

# %%
distiller = GatedKD(teacher_model, train_dataloaders, test_dataloaders, loss_fn=nn.KLDivLoss(), 
distill_weight=args['distill_weight'], temp=20)

# %%
kd_trainer = Trainer(deterministic=True)
kd_trainer.fit(distiller, train_dataloaders, val_dataloaders, callbacks=[EarlyStopping(monitor="val_kd_loss", mode="min")], min_steps=30, max_steps=100)

# %%
kd_trainer.test(dataloaders=test_dataloaders)

# %%
use_mean = False
#NAS.gating_threshold = 1e-2
student_model.NAS.verbose=True
student_model.estimate_required_channels(use_mean=use_mean)   
student_model.NAS.verbose=False
student_model.optimize(use_mean=use_mean, amount=0.4)
print("Improvment model size:", distiller.calc_improvement())

# %%
print(student_model)

# %%
# %%time
kd_trainer.test(dataloaders=test_dataloaders)
